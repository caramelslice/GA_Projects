# %%
### Statsmodels, because we love statsmodels,
### and because logistic regressions are still common for data exploration:from sklearn import datasets.
### Since logistic is used to solve binomial problems, our targets should be 0 and 1.
### by default, fit_regularized uses L1 Regularization
from sklearn import datasets
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
from sklearn import linear_model as lm

iris = datasets.load_iris()
irisdf = pd.DataFrame(iris.data, columns=['sep_len', 'sep_wid', 'pet_len', 'pet_wid'])
irisdf['target'] = iris.target
irisdf = irisdf.query('target in (1, 2)')
print irisdf['target']
irisdf['target'] = irisdf['target'] - 1
print irisdf['target']
irisdf
# Out:
# 50    1
# 51    1
# 52    1
# 53    1
# 54    1
# 55    1
# 56    1
# 57    1
# 58    1
# 59    1
# 60    1
# 61    1
# 62    1
# 63    1
# 64    1
# ...
# 135    2
# 136    2
# 137    2
# 138    2
# 139    2
# 140    2
# 141    2
# 142    2
# 143    2
# 144    2
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 100, dtype: int64
# 50    0
# 51    0
# 52    0
# 53    0
# 54    0
# 55    0
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# 61    0
# 62    0
# 63    0
# 64    0
# ...
# 135    1
# 136    1
# 137    1
# 138    1
# 139    1
# 140    1
# 141    1
# 142    1
# 143    1
# 144    1
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: target, Length: 100, dtype: int64
#      sep_len  sep_wid  pet_len  pet_wid  target
# 50       7.0      3.2      4.7      1.4       0
# 51       6.4      3.2      4.5      1.5       0
# 52       6.9      3.1      4.9      1.5       0
# 53       5.5      2.3      4.0      1.3       0
# ...

# %%
irisdf['target'] = irisdf['target'] - 1
lmf = smf.logit('target ~ sep_wid + pet_wid + sep_len', irisdf)
results = lmf.fit_regularized(alpha=0)
print results.summary()
print np.exp(results.params)
clf = lm.LogisticRegression(C=1e100).fit(irisdf[['sep_wid', 'pet_wid','sep_len']], irisdf['target'])
print clf.coef_
print np.exp(clf.coef_)
clf2 = lm.LogisticRegression(penalty='l1', C=1e100).fit(irisdf[['sep_wid', 'pet_wid','sep_len']], irisdf['target'])
print clf2.coef_
print np.exp(clf2.coef_)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0
#             Iterations: 20
#             Function evaluations: 214
#             Gradient evaluations: 20
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-36-0ce63f0d21ad> in <module>()
#       2 lmf = smf.logit('target ~ sep_wid + pet_wid + sep_len', irisdf)
#       3 results = lmf.fit_regularized(alpha=0)
# ----> 4 print results.summary()
#       5 print np.exp(results.params)
#       6 clf = lm.LogisticRegression(C=1e100).fit(irisdf[['sep_wid', 'pet_wid','sep_len']], irisdf['target'])
#
# /Users/caramel-slice/anaconda/lib/python2.7/site-packages/statsmodels/discrete/discrete_model.pyc in summary(self, yname, xname, title, alpha, yname_list)
#    2394                 yname_list=None):
# ...
